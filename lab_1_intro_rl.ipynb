# %% [markdown]
# <a href="https://colab.research.google.com/github/DiploDatos/AprendizajePorRefuerzos/blob/master/lab_1_intro_rl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 1: Introducción al aprendizaje por refuerzos
#
# Curso Aprendizaje por Refuerzos, Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones
#
# FaMAF, 2021

# %% [markdown]
# ## Introducción
#
# En el siguiente notebook se muestra cómo ejecutar agentes de aprendizaje por refuerzos, los cuáles son necesarios para realizar este Lab.

# %% [markdown]
# ## Librería usada: OpenAI Gym
#
# [OpenAI Gym](https://gym.openai.com/) (Brockman et al., 2016) es una librería de OpenAI que ofrece entornos y una interfaz estándar con la cuál probar nuestros agentes. Su objetivo es proveer benchmarks unificados para ver el desempeño de algoritmos en el entorno y así poder saber con facilidad cómo es su desempeño comparado con los demás. Parte de la siguiente sección está basada en la documentación oficial de OpenAI.

# %% [markdown]
# La interfaz principal de los ambientes de gym es la interfaz Env. La misma posee tres métodos principales (info. basada en la documentación oficial de Gym):
#
#
#     reset(self): Reinicia el estado del entorno, a su estado inicial, devolviendo una observación de dicho estado.
#     step(self, action): "Avanza" un timestep del ambiente. Devuelve: observation, reward, done, info.
#     render(self): Muestra en pantalla una parte del ambiente.
#     close(self): Finaliza con la instancia del agente.
#     seed(self): Establece la semilla aleatoria del generador de números aleatorios del presente entorno.
#
#
# Por otra parte, cada entorno posee los siguientes tres atributos principales:
#
#     action_space: El objeto de tipo Space correspondiente al espacio de acciones válidas.
#     observation_space: El objeto de tipo Space correspondiente a todos los rangos posibles de observaciones.
#     reward_range: Tupla que contiene los valores mínimo y máximo de recompensa posible.

# %% [markdown]
# Algunas de las ejecuciones contienen videos. Para poder verlos se necesita previamente instalar la librería ffmpeg. Para hacerlo desde Linux ejecutar en consola
#
# 	sudo apt-get install ffmpeg
#
# desde Windows descargarla desde
#
# [https://ffmpeg.org/download.html]()

# %% [markdown]
# Código básico de importación y funciones de graficación (no modificar)

# %%
#@title Código básico de graficación (no modificar)

import numpy as np
import matplotlib.pyplot as plt
import itertools
import gym

# %%
def plot_reward_per_episode(reward_ep):

    episode_rewards = np.array(reward_ep)

    # se suaviza la curva de convergencia
    episode_number = np.linspace(1, len(episode_rewards) + 1, len(episode_rewards) + 1)
    acumulated_rewards = np.cumsum(episode_rewards)

    reward_per_episode = [acumulated_rewards[i] / episode_number[i] for i in range(len(acumulated_rewards))]

    plt.plot(reward_per_episode)
    plt.title('Recompensa acumulada por episodio')
    plt.show()
    
    
def plot_steps_per_episode(timesteps_ep):
    # se muestra la curva de aprendizaje de los pasos por episodio
    episode_steps = np.array(timesteps_ep)
    plt.plot(np.array(range(0, len(episode_steps))), episode_steps)
    plt.title('Pasos (timesteps) por episodio')
    plt.show()
    
    
def plot_steps_per_episode_smooth(timesteps_ep):
    episode_steps = np.array(timesteps_ep)

    # se suaviza la curva de aprendizaje
    episode_number = np.linspace(1, len(episode_steps) + 1, len(episode_steps) + 1)
    acumulated_steps = np.cumsum(episode_steps)

    steps_per_episode = [acumulated_steps[i] / episode_number[i] for i in range(len(acumulated_steps))]

    plt.plot(steps_per_episode)
    plt.title('Pasos (timesteps) acumulados por episodio')
    plt.show()
    

def draw_value_matrix(q):

    n_rows = 4
    n_columns = 12
    n_actions = 4

    # se procede con los cálculos previos a la graficación de la matriz de valor
    q_value_matrix = np.empty((n_rows, n_columns))
    for row in range(n_rows):
        for column in range(n_columns):

            state_values = []

            for action in range(n_actions):
                state_values.append(q.get((row * n_columns + column, action), -100))

            maximum_value = max(state_values)  # determinamos la acción que arroja máximo valor


            q_value_matrix[row, column] = maximum_value

    # el valor del estado objetivo se asigna en -1 (reward recibido al llegar) para que se coloree de forma apropiada
    q_value_matrix[3, 11] = -1

    # se grafica la matriz de valor
    plt.imshow(q_value_matrix, cmap=plt.cm.RdYlGn)
    plt.tight_layout()
    plt.colorbar()

    for row, column in itertools.product(range(q_value_matrix.shape[0]), range(q_value_matrix.shape[1])):

        left_action = q.get((row * n_columns + column, 3), -1000)
        down_action = q.get((row * n_columns + column, 2), -1000)
        right_action = q.get((row * n_columns + column, 1), -1000)
        up_action = q.get((row * n_columns + column, 0), -1000)

        arrow_direction = 'D'
        best_action = down_action

        if best_action < right_action:
            arrow_direction = 'R'
            best_action = right_action
        if best_action < left_action:
            arrow_direction = 'L'
            best_action = left_action
        if best_action < up_action:
            arrow_direction = 'U'
            best_action = up_action
        if best_action == -1:
            arrow_direction = ''

        # notar que column, row están invertidos en orden en la línea de abajo porque representan a x,y del plot
        plt.text(column, row, arrow_direction, horizontalalignment="center")

    plt.xticks([])
    plt.yticks([])
    plt.show()

    print('\n Matriz de mejor acción-valor (en números): \n\n', q_value_matrix)

# %% [markdown]
# Ejemplo: agente CartPole

# %%
import gym
import time
from IPython.display import clear_output

try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# no es posible mostrar videos de ejecución del agente desde Colab
if not IN_COLAB:

    env = gym.make('CartPole-v0')
    env.reset()
    for _ in range(500):
        env.render(mode='human')
        observation, reward, done, info = env.step(env.action_space.sample()) # se ejecuta una acción aleatoria
        if done:
            env.reset()
    env.close()
    clear_output()

# %% [markdown]
# Ejemplo: agente Mountain Car

# %%
if not IN_COLAB:
    env = gym.make('MountainCar-v0')
    observation = env.reset()
    for t in range(500):
        env.render(mode='human')
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
    env.close()
    clear_output()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-02ce4e38b3ad> in <module>
# ----> 1 if not IN_COLAB:
#       2     env = gym.make('MountainCar-v0')
#       3     observation = env.reset()
#       4     for t in range(500):
#       5         env.render(mode='human')
#
# NameError: name 'IN_COLAB' is not defined

# %% [markdown]
# ## Ejemplo 1: The Cliff.

# %% [markdown]
# ![](https://github.com/GIDISIA/RLDiplodatos/blob/master/images/cliffwalking.png?raw=1)
#
# donde S= starting point, G= goal
#
# (imagen de Sutton y Barto, 2018)

# %% [markdown]
# Descripción del entorno:
#
# Acciones:
#
# * $\uparrow$ - Arriba
# * $\downarrow$ - Abajo
# * $\rightarrow$ - Derecha
# * $\leftarrow$ - Izquierda
#
# Función de recompensa:
#
# * $-1$ en todos los demás estados
# * $-100$ en el acantilado
#
# Nota: caer en el acantilado devuelve al agente al estado inicial en un mismo episodio

# %% [markdown]
# Vemos los bloques básicos de nuestro agente

# %% [markdown]
# Definimos el método de elección de acciones. En este caso el mismo utiliza la política de exploración $\epsilon$-greedy.

# %%
def choose_action(state, q_learning=False):
    """
    Chooses an action according to the learning previously performed 
    using an epsilon-greedy exploration policy
    """
    q_values = [q.get((state, a), 0.0) for a in actions]
    max_q = max(q_values)

    if random_state.uniform() < epsilon:
        return random_state.choice(actions)  # a random action is selected

    count = q_values.count(max_q)

    # In case there're several state-action max values
    # we select a random one among them
    if count > 1 and q_learning==False:
        best = [i for i in range(len(actions)) if q_values[i] == max_q]
        i = random_state.choice(best)
    else:
        i = q_values.index(max_q)

    return actions[i]

# %% [markdown]
# Definimos el esqueleto del método learn, el cuál toma una transición y cambia el dict de los valores de Q de acuerdo a algún algoritmo.

# %%
def learn(state, action, reward, next_state, next_action):
    """
    Performs a SARSA update for a given state transition
    """

    q_value = q.get((state, action), 0.0)
    q_next = q.get((next_state, next_action), 0.0)
    q[state,action] = q_value + alpha*(reward +( gamma*q_next )- q_value)


    
    pass

# %% [markdown]
# Finalmente, definimos el método principal de iteraciones.

# %%
def run(q_learning):
    """
    Runs the reinforcement learning agent with a given configuration.
    """
    # list that contains the amount of time-steps of the episode. It is used as a way to score the performance of
    # the agent.
    timesteps_of_episode = []
    # list that contains the amount of reward given to the agent in each episode
    reward_of_episode = []

    for i_episode in range(episodes_to_run):
        # an instance of an episode is run until it fails or until it reaches 200 time-steps

        # resets the environment, obtaining the first state observation
        state = env.reset()

        episode_reward = 0
        done = False
        t = 0

        # Pick an action based on the current state
        action = choose_action(state)
        
        while not done:

            # Execute the action and get feedback
            next_state, reward, done, info = env.step(action)

            next_action = choose_action(next_state, q_learning)          

            episode_reward += reward

            if not done and t < 2000:  # if the algorithm does not converge, it stops after 2000 timesteps
                learn(state, action, reward, next_state, next_action)
                state = next_state
                action = next_action
            else:
                done = True  # done is ensured to be True (in the case the algorithm did not reach convergence)
                learn(state, action, reward, next_state, next_action)
                timesteps_of_episode = np.append(timesteps_of_episode, [int(t + 1)])
                reward_of_episode = np.append(reward_of_episode, max(episode_reward, -100))

            t += 1

    return reward_of_episode.mean(), timesteps_of_episode, reward_of_episode

# %% [markdown]
# Definidos los métodos básicos, procedemos a instanciar a nuestro agente.

# %%
q = {}

# definimos sus híper-parámetros básicos

alpha = 0.5
gamma = 1
epsilon = 0.1
tau = 25

episodes_to_run = 1000

env = gym.make("CliffWalking-v0")
actions = range(env.action_space.n)

# se declara una semilla aleatoria
random_state = np.random.RandomState(42)

# %% [markdown]
# Ya instanciado, ejecutamos nuestro agente

# %%
avg_steps_per_episode, timesteps_ep, reward_ep = run(q_learning=False)

# %% [markdown]
# ### Análisis de la ejecución del agente
#
# #### Análisis de convergencia
#
# A diferencia de lo que sucede en el aprendizaje supervisado, en el aprendizaje por refuerzos el rendimiento se evalúa por una función específica que es la función de recompensa. En la práctica, la función de recompensa puede ser externa (y provista por el entorno) o bien puede ser una función creada por diseño (a modo de dirigir el agente hacia lo que por diseño se considera mejor, en nuestro ejemplo podría ser con una recompensa de $+1$ cada vez que el agente llega al estado objetivo). Esto se conoce como *reward shaping*, y hay que tener mucho cuidado con los posibles efectos secundarios de su uso.
#
# Como el objetivo de RL es maximizar la recompensa obtenida, es posible utilizar la información sobre la obtención de la recompensas en cada time-step o episodio para evaluar el rendimiento parcial del agente (esto depende mucho de la particularidad de la distribución de la recompensa para el problema tratado).

# %% [markdown]
# Para analizar la ejecución del agente, vamos a ver cómo se desempeñó el mismo en dos curvas:
#
# * Recompensa obtenida en cada episodio: nos dirá cuánta recompensa obtuvo el agente sumando cada una de recompensas individuales de cada episodio. Con esta medida podremos tener una noción de cómo se desempeñó esquivando el acantilado y llegando lo antes posible a la meta.
#
# * Pasos transcurridos en cada episodio: indicará cuántos pasos le ha llevado al agente la ejecución del episodio.
#
# Se estila suavizar ambas curvas para apreciar mejor su progresión (aunque a veces suele analizarse la curva de pasos por episodio sin suavizar).

# %% [markdown]
# Veamos recompensa por episodio (recordar que en este entorno cada paso otorga una recompensa de $-1$ excepto al caer al acantilado, donde la recompensa es de $-100$)

# %% [markdown]
# ### Ejecución con SARS

# %%
plot_reward_per_episode(reward_ep)

# %% [markdown]
# Veamos pasos por episodio

# %%
plot_steps_per_episode(timesteps_ep)

# %% [markdown]
# Suavizando...

# %%
plot_steps_per_episode_smooth(timesteps_ep)

# %% [markdown]
# #### Análisis de matriz de acción-valor y política óptima
#
# Siendo que este es un ejemplo tabular y de pocos estados / acciones, es posible realizar un análisis de convergencia desde otro punto de vista: desde el valor de la función $Q(s,a)$ para la mejor acción de cada estado, al finalizar el entrenamiento del agente, (sería la acción que el agente ejecutaría en cada estado bajo una política *greedy*). Ambos nos brindarán información sobre la convergencia alcanzada por el agente.
#
# Tener en cuenta que este análisis se hace principalmente con fines educativos, para entornos más complejos el mismo puede no ser factible. En tales casos, un análisis alternativo podría consistir en hacer que el agente ejecute su política para la que fue entrenado, para hacer una evaluación a partir del comportamiento del mismo (esto último sería el *test de la política*, frente al *entrenamiento de la política* previo).

# %%
draw_value_matrix(q)
# Out:
#  Matriz de mejor acción-valor (en números):
#
#  [[ -16.93448478  -15.71885702  -14.21568505  -12.63947329  -12.39872372
#    -10.12483287   -8.95993986   -7.70789537   -7.65774127   -6.52318231
#     -5.63988562   -5.61024597]
#  [ -18.27560581  -17.63498266  -14.98315437  -13.35920261  -12.39148524
#    -11.03537371  -10.7767126   -10.03718368   -7.48001488   -6.66807632
#     -3.74720056   -5.89478692]
#  [ -19.82057819  -16.81845897  -16.49223653  -15.236441    -13.78834951
#    -12.35609462  -10.85912787  -10.46984122   -9.24321249  -10.70408425
#     -2.10005112   -1.        ]
#  [ -21.09291907 -100.         -100.         -100.         -100.
#   -100.         -100.         -100.         -100.         -100.
#   -100.           -1.        ]]

# %%
env.close()

# %% [markdown]
# ### Ejecución con Q-Learning

# %%
avg_steps_per_episode, timesteps_ep, reward_ep = run(q_learning=True)

# %%
plot_reward_per_episode(reward_ep)

# %%
plot_steps_per_episode(timesteps_ep)

# %%
plot_steps_per_episode_smooth(timesteps_ep)

# %%
draw_value_matrix(q)
# Out:
#  Matriz de mejor acción-valor (en números):
#
#  [[ -22.64650048  -22.59589454  -21.90354542  -21.38290513  -22.04915881
#    -21.58507514  -21.14095302  -20.90074164  -20.14070858  -16.52288783
#     -9.34424107  -18.05721727]
#  [ -22.88555851  -22.95935868  -21.68187028  -20.85183998  -21.39482266
#    -21.3407927   -21.25342324  -20.68898388  -20.54929716  -19.15913836
#     -3.90908728  -14.55192087]
#  [ -23.20099863  -23.4872311   -19.45239776  -19.18579643  -22.23558039
#    -21.64706448  -21.84045037  -20.40544578   -9.78438831   -3.32647202
#     -2.00000308   -1.        ]
#  [ -22.00621081 -100.         -100.         -100.         -100.
#   -100.         -100.         -100.         -100.         -100.
#   -100.           -1.        ]]

# %% [markdown]
# ## Actividades
#
# 1. Implementar y ejecutar el algoritmo SARSA en "The Cliff".
#
# 2. Implementar y ejecutar el algoritmo Q-Learning en "The Cliff". ¿Cómo converge con respecto a SARSA? ¿A qué se debe? Comentar.
#
# 3. Ejecutando con distintos híper-parámetros, realizar una breve descripción sobre cómo afectan a la convergencia los distintos valores de $\alpha$, $\epsilon$ y $\gamma$.
#
# 4. (Opcional) Implementar política de exploración Softmax, en donde cada acción tiene una probabilidad $$\pi(a \mid s) = \frac{e^{Q(s,a)/\tau}}{\sum_{\dot{a} \in A}e^{Q(s,\dot{a})/\tau}}$$
#
#
#
# Para dejar el lab listo para su corrección, dejar link a repo de github con un notebook ejecutando el agente en la planilla enviada en Slack.

# %% [markdown]
# 2- Con respecto a SARSA:
# - En cuanto a la recompensa acumulada por episodio, Q-Learning inicia en un valor máximo y desciende a un mínimo en los primeros episodios. Luego comienza a incrementar, tendiendo a recompensas más altas. SARSA por otro lado inicia con la recompensa más baja en los primeros episodios y en los siguientes incrementa. (Aclaración: Con "primeros episodios" nos referimos a los episodios que van del 0 al 50 aproximadamente).
# - Y en cuanto a los pasos acumulados por episodio (tomando de referencia la curva suavizada), SARSA toma un valor máximo en los primeros episodios y luego tiende a cero en el resto de sus episodios, mientras que Q-Learning inicia en valores bajos en los primeros episodios, alcanza un máximo y luego tiende a cero en el resto de los episodios.
#
# Los picos y valles en las curvas del Q-learning se deben a que el agente siempre opta por acciones de mayor recompensa, por lo que tanto la recompensa acumulada como la cantidad de pasos acumulados por episodio, varían de una forma más brusca respecto a SARSA (donde varía gradualmente ya que es aleatoria la selección de la acción).

# %% [markdown]
# #### 3. Ejecución con distintos valores de hiperparámetros

# %%
def plot_reward_per_episode_values_custom(rewards_ep, values_to_plot, value_name):
    
    
    for i in range(len(rewards_ep)):
        
        episode_rewards = np.array(rewards_ep[i])
        
        episode_number = np.linspace(1, len(episode_rewards) + 1, len(episode_rewards) + 1)
        acumulated_rewards = np.cumsum(episode_rewards)

        reward_per_episode = [acumulated_rewards[i] / episode_number[i] for i in range(len(acumulated_rewards))]

        plt.plot(reward_per_episode, label=values_to_plot[i])
        
    plt.title(f'Recompensa acumulada por episodio con distintos {value_name}')
    plt.legend()
    plt.show()
    
def plot_steps_per_episode_values_custom(timesteps_ep , values_to_plot, value_name):
    
    for i in range(len(timesteps_ep)):
        episode_steps = np.array(timesteps_ep[i])
        plt.plot(np.array(range(0, len(episode_steps))), episode_steps, label=values_to_plot[i])

    plt.title(f'Timesteps episodio con distintos {value_name}')
    plt.legend()
    plt.show()
    
    
def plot_steps_per_episode_smooth_values_custom(timesteps_ep, values_to_plot, value_name):
    
    for j in range(len(timesteps_ep)):
        episode_steps = np.array(timesteps_ep[j])

        episode_number = np.linspace(1, len(episode_steps) + 1, len(episode_steps) + 1)
        acumulated_steps = np.cumsum(episode_steps)

        steps_per_episode = [acumulated_steps[i] / episode_number[i] for i in range(len(acumulated_steps))]

        plt.plot(steps_per_episode, label=values_to_plot[j])
    
    plt.title(f'Pasos (timesteps) acumulados por episodio con distintos {value_name})')
    plt.legend()
    plt.show()

# %%
q = {}
episodes_to_run = 1000


alphas = [0.1, 0.3, 0.5, 0.7, 1]
gammas = [0.1, 0.3, 0.5, 0.7, 1]
epsilons = [0.1, 0.5, 1]
taus = 25

env = gym.make("CliffWalking-v0")
actions = range(env.action_space.n)

# se declara una semilla aleatoria
random_state = np.random.RandomState(42)

# %% [markdown]
# #### Reward y timesteps con distintos alphas

# %%
rewards_per_alpha = list()
timesteps_per_alpha = list()
timesteps_smooth_per_alpha = list()

for alpha in alphas:

    avg_steps_per_episode, timesteps_ep, reward_ep = run(q_learning=False)
    rewards_per_alpha.append(reward_ep)
    timesteps_per_alpha.append(timesteps_ep)
    timesteps_smooth_per_alpha.append(timesteps_ep)
    
plot_reward_per_episode_values_custom(rewards_per_alpha, alphas, 'alphas')
plot_steps_per_episode_values_custom(timesteps_per_alpha, alphas, 'alphas')
plot_steps_per_episode_smooth_values_custom(timesteps_smooth_per_alpha, alphas, 'alphas')

# %% [markdown]
# En este determinado escenario, podemos visualizar en base a los gráficos que, en cuanto a recompensa acumulada, con alpha de 0.1, esta comienza a incrementar desde los primeros episodios y tiende a 0 en el infinito, en valores dentro del intérvalo (0.3, 0.5), alcanza un máximo en sus primeros episodios y luego desciende gradualmente y se mantiene en el infinito mientras que con un alpha 1, a medida que avanza hacia el final de los episodios comienza a descender hacia el infinito.
# En cuanto a los timesteps acumulados por episodio, con un alpha de 0.1 inicia en su valor máximo y tiene a cero en el inifito, con un alpha de 1 se incrementa gradualmente y el resto presenta un comportamiento muy similar y bastante estable a lo largo de los episodios (teniendo en cuenta la curva suavizada).

# %% [markdown]
# #### Reward y timesteps con distintos gammas

# %%
rewards_per_gamma = list()
timesteps_per_gamma  = list()
timesteps_smooth_per_gamma = list()

for gamma in gammas:

    avg_steps_per_episode, timesteps_ep, reward_ep = run(q_learning=False)
    rewards_per_gamma.append(reward_ep)
    timesteps_per_gamma.append(timesteps_ep)
    timesteps_smooth_per_gamma.append(timesteps_ep)
    
plot_reward_per_episode_values_custom(rewards_per_gamma, gammas, 'gammas')
plot_steps_per_episode_values_custom(timesteps_per_gamma, gammas, 'gammas')
plot_steps_per_episode_smooth_values_custom(timesteps_smooth_per_gamma, gammas, 'gammas')

# %% [markdown]
# En cuanto a los distintos gammas, podemos ver que en este caso a pesar de que las curvas de recompensa acumulada adquieren un comportamiento muy similar en los distintos valores, a mayor gamma, mayor es la recompensa a lo largo de los episodios. En cuanto a los timesteps acumulados y teniendo en cuenta las curvas suavizadas, a mayor gamma, menor es la cantidad de timesteps acumulados por episodio.

# %% [markdown]
# #### Reward y timesteps con distintos epsilons

# %%
rewards_per_epsilon = list()
timesteps_per_epsilon  = list()
timesteps_smooth_per_epsilon = list()

for epsilon in epsilons:

    avg_steps_per_episode, timesteps_ep, reward_ep = run(q_learning=False)
    rewards_per_epsilon.append(reward_ep)
    timesteps_per_epsilon.append(timesteps_ep)
    timesteps_smooth_per_epsilon.append(timesteps_ep)
    
plot_reward_per_episode_values_custom(rewards_per_epsilon, epsilons, 'epsilon')
plot_steps_per_episode_values_custom(timesteps_per_epsilon, epsilons, 'epsilon')
plot_steps_per_episode_smooth_values_custom(timesteps_smooth_per_epsilon, epsilons, 'epsilon')

# %% [markdown]
# Resopecto a los distintos valores de epsilon y en términos de recompensa, la variación de la recompensa acumulada no es tan significativa como en el resto de los hiperparámetros pero podemos ver que a menor epsilon, mayor es la recompensa acumulada a lo largo de los episodios. Por otro lado, en cuanto a timesteps acumulados por episodio, al variar epsilon, las distintas curvas suavizadas se comportan muy parecido pero la que presenta menor cantidad de pasos acumulados es aquella asociada a un epsilon de 0.1. En base a esto, podemos visualiza que a mayor epsilon, mayor cantidad de timesteps acumulados por episodio.
